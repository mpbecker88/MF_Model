# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from math import erf
from mpmath import mp
from scipy import integrate
from scipy.integrate import simpson
from scipy.special import erf
from dataclasses import dataclass, field
from sklearn.metrics import mean_squared_error

mp.dps = 550

# Customize matplotlib
matplotlib.rcParams.update(
	{
		'text.usetex': False,
		'font.family': 'stixgeneral',
		'mathtext.fontset': 'stix',
		'font.size': 22,
		'ytick.color' : 'black',
		"xtick.color" : 'black',
		'axes.labelcolor' : 'black',
		'axes.edgecolor' : 'black'
	}
)

# %%
@dataclass
class Parameters:
    Vth:float
    Vr: float
    KE: int
    KI: int
    wE: float
    wI: float
    tauE: float
    tauI: float
    tauL: float
    tauR: float
    EE: float
    EI: float
    EL: float
    nu: float

    muE: float = field(init=False)
    muI: float = field(init=False)
    sigmaE: float = field(init=False)
    sigmaI: float = field(init=False)
    mu: float = field(init=False)
    tau: float = field(init=False)
    hE: float = field(init=False)
    hI: float = field(init=False)

    def __post_init__(self):
        self.recalculate()

    def recalculate(self):
        self.muE = self.wE*self.KE*self.nu*self.tauE
        self.muI = self.wI*self.KI*self.nu*self.tauI
        self.sigmaE = self.wE*np.sqrt(self.KE*self.nu*self.tauE)
        self.sigmaI = self.wI*np.sqrt(self.KI*self.nu*self.tauI)
        self.tau = self.tauL/(1 + self.muE + self.muI)
        self.mu = self.tau*(self.EL + self.muE*self.EE + self.muI*self.EI)/self.tauL
        self.hE = (self.tau/self.tauL)*self.sigmaE*(self.EE - self.mu)
        self.hI = (self.tau/self.tauL)*self.sigmaI*(self.EI - self.mu)

    def set_tauE(self, tauE):
        self.tauE = tauE
        self.recalculate()

    def set_nu(self, nu):
        self.nu = nu
        self.recalculate()

    def calculate_sigma(self):
        return np.sqrt((self.tauE * self.hE**2)/(self.tau + self.tauE) + (self.tauI * self.hI**2)/(self.tau + self.tauI))

# %%
data_directory_path = "../../Data/V_data/"

df_varV_iRate = pd.read_csv(f"{data_directory_path}var_V_ta_iRate.dat", index_col=0)
df_varV_wE = pd.read_csv(f"{data_directory_path}var_V_ta_wE.dat", index_col=0)
df_varV_wI = pd.read_csv(f"{data_directory_path}var_V_ta_wI.dat", index_col=0)

df_meanV_iRate = pd.read_csv(f"{data_directory_path}mean_V_ta_iRate.dat", index_col=0)
df_meanV_wE = pd.read_csv(f"{data_directory_path}mean_V_ta_wE.dat", index_col=0)
df_meanV_wI = pd.read_csv(f"{data_directory_path}mean_V_ta_wI.dat", index_col=0)

df_varV_wE
# Out:
#           tauA        0.1          1         10
# 0      0.10000   0.984611   2.786785  39.091041
# 1      0.60201   1.994359  22.130284  56.935961
# 2      1.10402   3.286929  36.024960  33.866656
# 3      1.60603   4.464559  43.603256  18.984020
# 4      2.10804   5.790445  45.896427  11.573119
# ..         ...        ...        ...        ...
# 195   97.99196   9.908226   0.249369        NaN
# 196   98.49397  10.446445   0.251601        NaN
# 197   98.99598   9.887206   0.258558        NaN
# 198   99.49799  10.442403   0.222809        NaN
# 199  100.00000  10.027684   0.242609        NaN
#
# [200 rows x 4 columns]

# %%
vec_tauE = np.linspace(0.1, 100, 100)
vec_iRate = np.array([0.005, 0.01, 0.02])
vec_wE = np.array([0.1, 1.0, 10])
vec_wI = np.array([0.1, 1.0, 10])
dic_varV_iRate = {vec_iRate[0]:np.zeros_like(vec_tauE), vec_iRate[1]:np.zeros_like(vec_tauE), vec_iRate[2]:np.zeros_like(vec_tauE)}
dic_varV_wE = {vec_wE[0]:np.zeros_like(vec_tauE), vec_wE[1]:np.zeros_like(vec_tauE), vec_wE[2]:np.zeros_like(vec_tauE)}
dic_varV_wI = {vec_wI[0]:np.zeros_like(vec_tauE), vec_wI[1]:np.zeros_like(vec_tauE), vec_wI[2]:np.zeros_like(vec_tauE)}
dic_meanV_iRate = {vec_iRate[0]:np.zeros_like(vec_tauE), vec_iRate[1]:np.zeros_like(vec_tauE), vec_iRate[2]:np.zeros_like(vec_tauE)}
dic_meanV_wE = {vec_wE[0]:np.zeros_like(vec_tauE), vec_wE[1]:np.zeros_like(vec_tauE), vec_wE[2]:np.zeros_like(vec_tauE)}
dic_meanV_wI = {vec_wI[0]:np.zeros_like(vec_tauE), vec_wI[1]:np.zeros_like(vec_tauE), vec_wI[2]:np.zeros_like(vec_tauE)}

# %%
for iRate in vec_iRate:
	for i, tauE in enumerate(vec_tauE):
		parameters = Parameters(Vth=-50, Vr=-60, KE=400, KI=100, wE=0.1, wI=0.4, tauE=tauE, tauI=10, tauL=20, tauR=2, EE=0, EI=-80, EL=-60, nu=iRate)

		dic_varV_iRate[iRate][i] = parameters.calculate_sigma()
		dic_meanV_iRate[iRate][i] = parameters.mu

for wE in vec_wE:
	for i, tauE in enumerate(vec_tauE):
		parameters = Parameters(Vth=-50, Vr=-60, KE=400, KI=100, wE=wE, wI=0.8, tauE=tauE, tauI=10, tauL=20, tauR=2, EE=0, EI=-80, EL=-60, nu=0.005)

		dic_varV_wE[wE][i] = parameters.calculate_sigma()
		dic_meanV_wE[wE][i] = parameters.mu

for wI in vec_wI:
	for i, tauE in enumerate(vec_tauE):
		parameters = Parameters(Vth=-50, Vr=-60, KE=400, KI=100, wE=0.5, wI=wI, tauE=tauE, tauI=10, tauL=20, tauR=2, EE=0, EI=-80, EL=-60, nu=0.005)

		dic_varV_wI[wI][i] = parameters.calculate_sigma()
		dic_meanV_wI[wI][i] = parameters.mu

# %%
df_meanV_wE2 = pd.read_csv(f"{data_directory_path}mean_V_ta_wE_2.dat", index_col=0)
df_meanV_wE2
# Out:
#          tauA        0.1          1        10
# 0    2.337504 -69.246006 -39.148968 -7.830741
# 1   96.011346 -15.438939  -1.919499 -0.199582
# 2   26.856078 -36.389432  -6.519774 -0.708829
# 3   90.497352 -16.175296  -2.036381 -0.209671
# 4   98.763682 -15.259462  -1.877687 -0.194034
# ..        ...        ...        ...       ...
# 95  92.400147 -16.024060  -2.004164 -0.207781
# 96  49.959831 -25.048871  -3.581658 -0.379359
# 97  54.642241 -23.424096  -3.336307 -0.343484
# 98  23.768695 -38.431184  -7.283110 -0.790180
# 99  22.558946 -39.579797  -7.481266 -0.844481
#
# [100 rows x 4 columns]

# %%
fig, axs = plt.subplots(2, 3, figsize=(22,12), dpi=100)

axs[0][0].set_ylabel(r'$\mu$')
axs[1][0].set_xlabel(r'$\tau_E$ [ms]')
axs[1][0].set_ylabel(r'$\sigma_V^2/2$')

axs[0][0].set_ylim(-80, 0)
axs[0][0].plot(df_meanV_iRate['tauA'], df_meanV_iRate['5'], 'b.', ms=10, markerfacecolor='none')
axs[0][0].plot(df_meanV_iRate['tauA'], df_meanV_iRate['10'], 'r.', ms=10, markerfacecolor='none')
axs[0][0].plot(df_meanV_iRate['tauA'], df_meanV_iRate['20'], 'g.', ms=10, markerfacecolor='none')
axs[0][0].plot(vec_tauE, dic_meanV_iRate[vec_iRate[0]], 'b-', label='input = 5HZ')
axs[0][0].plot(vec_tauE, dic_meanV_iRate[vec_iRate[1]], 'r-', label='input = 10HZ')
axs[0][0].plot(vec_tauE, dic_meanV_iRate[vec_iRate[2]], 'g-', label='input = 20HZ')
axs[0][0].legend(bbox_to_anchor=(0.98, 0.28), loc=1, borderaxespad=0., prop={'size': 14})

axs[0][1].set_ylim(-80, 0)
axs[0][1].plot(df_meanV_wE['tauA'], df_meanV_wE['0.1'], 'b.', markerfacecolor='none')
axs[0][1].plot(df_meanV_wE['tauA'], df_meanV_wE['1'], 'r.', markerfacecolor='none')
axs[0][1].plot(df_meanV_wE['tauA'], df_meanV_wE['10'], 'g.', markerfacecolor='none')
axs[0][1].plot(vec_tauE, dic_meanV_wE[vec_wE[0]], 'b-', label=r'$w_E = 0.1$')
axs[0][1].plot(vec_tauE, dic_meanV_wE[vec_wE[1]], 'r-', label=r'$w_E = 1.0$')
axs[0][1].plot(vec_tauE, dic_meanV_wE[vec_wE[2]], 'g-', label=r'$w_E = 10.0$')
axs[0][1].legend(bbox_to_anchor=(0.98, 0.28), loc=1, borderaxespad=0., prop={'size': 14})

axs[0][2].set_ylim(-80, 0)
axs[0][2].plot(df_meanV_wI['tauA'], df_meanV_wI['0.1'], 'b.', markerfacecolor='none')
axs[0][2].plot(df_meanV_wI['tauA'], df_meanV_wI['1'], 'r.', markerfacecolor='none')
axs[0][2].plot(df_meanV_wI['tauA'], df_meanV_wI['10'], 'g.', markerfacecolor='none')
axs[0][2].plot(vec_tauE, dic_meanV_wI[vec_wI[0]], 'b-', label=r'$w_I = 0.1$')
axs[0][2].plot(vec_tauE, dic_meanV_wI[vec_wI[1]], 'r-', label=r'$w_I = 1.0$')
axs[0][2].plot(vec_tauE, dic_meanV_wI[vec_wI[2]], 'g-', label=r'$w_I = 10.0$')
axs[0][2].legend(bbox_to_anchor=(0.98, 0.28), loc=1, borderaxespad=0., prop={'size': 14})

axs[1][0].set_ylim(-1, 50)
axs[1][0].plot(df_varV_iRate['tauA'], df_varV_iRate['5'], 'b.', markerfacecolor='none')
axs[1][0].plot(df_varV_iRate['tauA'], df_varV_iRate['10'], 'r.', markerfacecolor='none')
axs[1][0].plot(df_varV_iRate['tauA'], df_varV_iRate['20'], 'g.', markerfacecolor='none')
axs[1][0].plot(vec_tauE, dic_varV_iRate[vec_iRate[0]]**2/2, 'b-', label='input = 5HZ')
axs[1][0].plot(vec_tauE, dic_varV_iRate[vec_iRate[1]]**2/2, 'r-', label='input = 10HZ')
axs[1][0].plot(vec_tauE, dic_varV_iRate[vec_iRate[2]]**2/2, 'g-', label='input = 20HZ')
axs[1][0].legend(bbox_to_anchor=(0.98, 0.98), loc=1, borderaxespad=0., prop={'size': 14})

axs[1][1].set_xlabel(r'$\tau_E$ [ms]')

axs[1][1].set_ylim(-1, 50)
axs[1][1].plot(df_varV_wE['tauA'], df_varV_wE['0.1'], 'b.', markerfacecolor='none')
axs[1][1].plot(df_varV_wE['tauA'], df_varV_wE['1'], 'r.', markerfacecolor='none')
axs[1][1].plot(df_varV_wE['tauA'], df_varV_wE['10'], 'g.', markerfacecolor='none')
axs[1][1].plot(vec_tauE, dic_varV_wE[vec_wE[0]]**2/2, 'b-', label=r'$w_E = 0.1$')
axs[1][1].plot(vec_tauE, dic_varV_wE[vec_wE[1]]**2/2, 'r-', label=r'$w_E = 1.0$')
axs[1][1].plot(vec_tauE, dic_varV_wE[vec_wE[2]]**2/2, 'g-', label=r'$w_E = 10.0$')
axs[1][1].legend(bbox_to_anchor=(0.98, 0.98), loc=1, borderaxespad=0., prop={'size': 14})

axs[1][2].set_xlabel(r'$\tau_E$ [ms]')

axs[1][2].set_ylim(-1, 50)
axs[1][2].plot(df_varV_wI['tauA'], df_varV_wI['0.1'], 'b.', markerfacecolor='none')
axs[1][2].plot(df_varV_wI['tauA'], df_varV_wI['1'], 'r.', markerfacecolor='none')
axs[1][2].plot(df_varV_wI['tauA'], df_varV_wI['10'], 'g.', markerfacecolor='none')
axs[1][2].plot(vec_tauE, dic_varV_wI[vec_wI[0]]**2/2, 'b-', label=r'$w_I = 0.1$')
axs[1][2].plot(vec_tauE, dic_varV_wI[vec_wI[1]]**2/2, 'r-', label=r'$w_I = 1.0$')
axs[1][2].plot(vec_tauE, dic_varV_wI[vec_wI[2]]**2/2, 'g-', label=r'$w_I = 10.0$')
axs[1][2].legend(bbox_to_anchor=(0.98, 0.98), loc=1, borderaxespad=0., prop={'size': 14})

# %%
df_nu_iRate = pd.read_csv('firing_rate_iRate.dat', index_col=0)
df_nu_iRate_analytic = pd.read_csv('analytic_fRate_iRate.dat')

df_nu_wE = pd.read_csv('firing_rate_wE.dat', index_col=0)
df_nu_wE_analytic = pd.read_csv('analytic_fRate_wE.dat')

df_nu_wI = pd.read_csv('firing_rate_wI.dat', index_col=0)
df_nu_wI_analytic = pd.read_csv('analytic_fRate_wI.dat')

df_nu_iRate_analy
# Out:
#           tauA             5             10             20
# 0      0.10000  4.191681e-84  9.926694e-287   0.000000e+00
# 1      0.60201  4.989175e-37   6.517563e-74  1.774996e-139
# 2      1.10402  3.835981e-19   2.942282e-30   1.217239e-48
# 3      1.60603  2.971715e-11   1.262802e-15   2.006811e-23
# 4      2.10804  2.830676e-07   3.389414e-09   4.467307e-13
# ..         ...           ...            ...            ...
# 195   97.99196  4.553820e-01   4.766885e-01   4.880758e-01
# 196   98.49397  4.555999e-01   4.768075e-01   4.881381e-01
# 197   98.99598  4.558157e-01   4.769253e-01   4.881998e-01
# 198   99.49799  4.560295e-01   4.770419e-01   4.882608e-01
# 199  100.00000  4.562411e-01   4.771573e-01   4.883940e-01
#
# [200 rows x 4 columns]

# %%
fig, axs = plt.subplots(2, 3, figsize=(22,12), dpi=100)

axs[0][0].set_ylabel(r'$\sigma_V^2/2$')

axs[0][0].set_ylim(-1, 50)
axs[0][0].plot(df_varV_iRate['tau (nu=5)'][:-100], df_varV_iRate['5'][:-100], 'b.', markerfacecolor='none')
axs[0][0].plot(df_varV_iRate['tau (nu=10)'][:-100], df_varV_iRate['10'][:-100], 'r.', markerfacecolor='none')
axs[0][0].plot(df_varV_iRate['tau (nu=20)'][:-100], df_varV_iRate['20'][:-100], 'g.', markerfacecolor='none')
axs[0][0].plot(vec_tauE, dic_varV_iRate[vec_iRate[0]]**2/2, 'b-', label='input = 5HZ')
axs[0][0].plot(vec_tauE, dic_varV_iRate[vec_iRate[1]]**2/2, 'r-', label='input = 10HZ')
axs[0][0].plot(vec_tauE, dic_varV_iRate[vec_iRate[2]]**2/2, 'g-', label='input = 20HZ')
axs[0][0].legend(bbox_to_anchor=(0.98, 0.98), loc=1, borderaxespad=0., prop={'size': 14})


axs[0][1].set_ylim(-1, 50)
axs[0][1].plot(df_varV_wE['tauA'], df_varV_wE['0.1'], 'b.', markerfacecolor='none')
axs[0][1].plot(df_varV_wE['tauA'], df_varV_wE['1'], 'r.', markerfacecolor='none')
axs[0][1].plot(df_varV_wE['tauA'], df_varV_wE['10'], 'g.', markerfacecolor='none')
axs[0][1].plot(vec_tauE, dic_varV_wE[vec_wE[0]]**2/2, 'b-', label=r'$w_E = 0.1$')
axs[0][1].plot(vec_tauE, dic_varV_wE[vec_wE[1]]**2/2, 'r-', label=r'$w_E = 1.0$')
axs[0][1].plot(vec_tauE, dic_varV_wE[vec_wE[2]]**2/2, 'g-', label=r'$w_E = 10.0$')
axs[0][1].legend(bbox_to_anchor=(0.98, 0.98), loc=1, borderaxespad=0., prop={'size': 14})


axs[0][2].set_ylim(-1, 50)
# axs[0][2].plot(df_varV_wI['tauA'], df_varV_wI['0.1'], 'b.', markerfacecolor='none')
axs[0][2].plot(df_varV_wI['tauA'], df_varV_wI['1'], 'r.', markerfacecolor='none')
axs[0][2].plot(df_varV_wI['tauA'], df_varV_wI['10'], 'g.', markerfacecolor='none')
# axs[0][2].plot(vec_tauE, dic_varV_wI[vec_wI[0]]**2/2, 'b-', label=r'$w_I = 0.1$')
axs[0][2].plot(vec_tauE, dic_varV_wI[vec_wI[1]]**2/2, 'r-', label=r'$w_I = 1.0$')
axs[0][2].plot(vec_tauE, dic_varV_wI[vec_wI[2]]**2/2, 'g-', label=r'$w_I = 10.0$')
axs[0][2].legend(bbox_to_anchor=(0.98, 0.98), loc=1, borderaxespad=0., prop={'size': 14})


axs[1][0].set_xlabel(r'$\tau_E$ [ms]')
axs[1][0].set_ylabel(r'$\nu \, [Hz]$')

axs[1][0].plot(df_nu_iRate['tauA'], df_nu_iRate['5'], 'b.', markerfacecolor='none')
axs[1][0].plot(df_nu_iRate['tauA'], df_nu_iRate['10'], 'r.', markerfacecolor='none')
axs[1][0].plot(df_nu_iRate['tauA'], df_nu_iRate['20'], 'g.', markerfacecolor='none')
axs[1][0].plot(df_nu_iRate_analytic['tauA'], df_nu_iRate_analytic['5']*1000, 'b-', label='input = 5HZ')
axs[1][0].plot(df_nu_iRate_analytic['tauA'], df_nu_iRate_analytic['10']*1000, 'r-', label='input = 10HZ')
axs[1][0].plot(df_nu_iRate_analytic['tauA'], df_nu_iRate_analytic['20']*1000, 'g-', label='input = 20HZ')
axs[1][0].legend(bbox_to_anchor=(0.98, 0.24), loc=1, borderaxespad=0., prop={'size': 14})

axs[1][1].set_xlabel(r'$\tau_E$ [ms]')

axs[1][1].plot(df_nu_wE['tauA'], df_nu_wE['0.1'], 'b.', markerfacecolor='none')
axs[1][1].plot(df_nu_wE['tauA'], df_nu_wE['1'], 'r.', markerfacecolor='none')
axs[1][1].plot(df_nu_wE['tauA'], df_nu_wE['10'], 'g.', markerfacecolor='none')
axs[1][1].plot(df_nu_wE_analytic['tauA'], df_nu_wE_analytic['0.1']*1000, 'b-', label=r'$w_E = 0.1$')
axs[1][1].plot(df_nu_wE_analytic['tauA'], df_nu_wE_analytic['1']*1000, 'r-', label=r'$w_E = 1.0$')
axs[1][1].plot(df_nu_wE_analytic['tauA'], df_nu_wE_analytic['10']*1000, 'g-', label=r'$w_E = 10.0$')
axs[1][1].legend(bbox_to_anchor=(0.98, 0.24), loc=1, borderaxespad=0., prop={'size': 14})

axs[1][2].set_xlabel(r'$\tau_E$ [ms]')

axs[1][2].plot(df_nu_wI['tauA'], df_nu_wI['0.1'], 'b.', markerfacecolor='none')
axs[1][2].plot(df_nu_wI['tauA'], df_nu_wI['1'], 'r.', markerfacecolor='none')
axs[1][2].plot(df_nu_wI['tauA'], df_nu_wI['10'], 'g.', markerfacecolor='none')
axs[1][2].plot(df_nu_wI_analytic['tauA'], df_nu_wI_analytic['0.1']*1000, 'b-', label=r'$w_I = 0.1$')
axs[1][2].plot(df_nu_wI_analytic['tauA'], df_nu_wI_analytic['1']*1000, 'r-', label=r'$w_I = 1.0$')
axs[1][2].plot(df_nu_wI_analytic['tauA'], df_nu_wI_analytic['10']*1000, 'g-', label=r'$w_I = 10.0$')
axs[1][2].legend(bbox_to_anchor=(0.98, 0.24), loc=1, borderaxespad=0., prop={'size': 14})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/marcelo/Worklab/MF_Model/Notebooks/Model_Comparison/MF_model_comparison_V.ipynb Cell 8' in <module>
#      <a href='vscode-notebook-cell:/home/marcelo/Worklab/MF_Model/Notebooks/Model_Comparison/MF_model_comparison_V.ipynb#ch0000007?line=34'>35</a> axs[1][0].set_xlabel(r'$\tau_E$ [ms]')
#      <a href='vscode-notebook-cell:/home/marcelo/Worklab/MF_Model/Notebooks/Model_Comparison/MF_model_comparison_V.ipynb#ch0000007?line=35'>36</a> axs[1][0].set_ylabel(r'$\nu \, [Hz]$')
# ---> <a href='vscode-notebook-cell:/home/marcelo/Worklab/MF_Model/Notebooks/Model_Comparison/MF_model_comparison_V.ipynb#ch0000007?line=37'>38</a> axs[1][0].plot(df_nu_iRate['tauA'], df_nu_iRate['5'], 'b.', markerfacecolor='none')
#      <a href='vscode-notebook-cell:/home/marcelo/Worklab/MF_Model/Notebooks/Model_Comparison/MF_model_comparison_V.ipynb#ch0000007?line=38'>39</a> axs[1][0].plot(df_nu_iRate['tauA'], df_nu_iRate['10'], 'r.', markerfacecolor='none')
#      <a href='vscode-notebook-cell:/home/marcelo/Worklab/MF_Model/Notebooks/Model_Comparison/MF_model_comparison_V.ipynb#ch0000007?line=39'>40</a> axs[1][0].plot(df_nu_iRate['tauA'], df_nu_iRate['20'], 'g.', markerfacecolor='none')
#
# NameError: name 'df_nu_iRate' is not defined
